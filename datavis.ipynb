# %% [markdown]
# <a href="https://colab.research.google.com/github/SSSpock/skillspire/blob/main/datavis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Introduction to Data Visualization

# %% [markdown]
# ## Importance of Data Visualization
# Data visualization is a key aspect of data science, as it allows us to better understand and communicate complex information. By representing data in a visual format, we can:
#
# Quickly grasp essential information and patterns in the data
# Identify outliers and anomalies
# Make informed decisions based on the data
# Communicate our findings to others in a clear and concise manner

# %% [markdown]
# ## Types of Data Visualizations
# There are many types of data visualizations, each suited to different types of data and purposes. Some common types include:
#
# Line plots: Display continuous data over time or another variable
#
# Bar plots: Compare categorical data or show the distribution of values across categories
#
# Scatter plots: Show the relationship between two continuous variables
#
# Histograms: Display the distribution of a continuous variable
#
# Pie charts: Show proportions of a whole
#
# Heatmaps: Represent data in a matrix format, using colors to indicate values
#
# Box plots: Visualize the distribution of data and identify outliers
#
# Area charts: Display continuous data over time or another variable, with emphasis on the magnitude

# %% [markdown]
# ## Applications in Data Science
# Data visualization plays a crucial role in various stages of data science, including:
#
# Exploratory Data Analysis (EDA): Visualization helps identify patterns, trends, and relationships in the data, which can guide the development of hypotheses and inform feature selection.
#
# Model Evaluation: Visualizing model performance, such as learning curves or confusion matrices, can help us understand the strengths and weaknesses of our models and guide improvements.
#
# Reporting and Communication: Creating clear and informative visualizations can help communicate our findings to stakeholders and facilitate data-driven decision-making.

# %% [markdown]
# # Introduction to Matplotlib

# %% [markdown]
# ## Overview of the Matplotlib Library
#
# Matplotlib is a powerful and popular Python library for creating static, animated, and interactive visualizations. It provides a wide range of plotting functions, enabling users to create various types of visualizations with ease.
#
# Some key features of Matplotlib include:
#
# High-quality output in multiple formats (PNG, PDF, SVG, etc.)
# Extensive customization options for plot appearance
# Integration with Jupyter Notebook and other Python libraries

# %% [markdown]
# ## Basic Plotting Functions
#
# Matplotlib provides several basic plotting functions for creating various types of plots. Here are a few common ones:
#
# plot(): Creates line plots
#
# scatter(): Creates scatter plots
#
# bar(): Creates bar plots
#
# hist(): Creates histograms
#
# boxplot(): Creates box plots
#
# pie(): Creates pie charts

# %% [markdown]
# ## Customizing Plots
# With Matplotlib, you can customize various aspects of your plots to make them more informative and visually appealing. Some common customizations include:
#
# Adding titles, axis labels, and legends
# Changing line styles, colors, and markers
# Modifying axis limits and ticks
# Annotating plots with text, arrows, or other shapes
# Applying gridlines and background colors

# %% [markdown]
# # Understanding Matplotlib Control Patterns
#
# In this section, we will explain the high-level control patterns in Matplotlib, specifically focusing on the use of functions like plt.title() and how they can access and modify elements of your plots.

# %% [markdown]
# ## Matplotlib's Object Hierarchy
# At its core, Matplotlib is built on an object-oriented hierarchy. At the top of this hierarchy is the Figure object, which represents the entire plot and can contain one or more Axes objects. Each Axes object represents a single plot within the figure and contains various elements, such as lines, markers, labels, and more.
#
# When you create a plot using Matplotlib functions like plt.plot(), you are implicitly working with the Figure and Axes objects in the background. The pyplot (imported as plt) interface provides a simple way to interact with these objects without explicitly referencing them.

# %% [markdown]
# ## The Pyplot State Machine
# Matplotlib's pyplot interface operates as a state machine. It keeps track of the current Figure and Axes objects, and most pyplot functions implicitly target the current objects. When you call functions like plt.title(), they access and modify elements of the current Axes object.
#
# Here's a brief overview of how some common pyplot functions interact with the object hierarchy:
#
# plt.figure(): Creates a new Figure object and sets it as the current figure
#
# plt.plot(), plt.scatter(), etc.: Creates the corresponding plot element within the current Axes object
#
# plt.title(), plt.xlabel(), plt.ylabel(): Sets the title, x-axis label, or y-axis label of the current Axes object
#
# plt.legend(): Adds a legend to the current Axes object
#
# plt.show(): Displays the current Figure object

# %% [markdown]
# ## Working with Multiple Figures and Axes
# In some cases, you may want to create multiple figures or axes within a single plot. You can achieve this by explicitly creating and referencing Figure and Axes objects using the plt.subplots() function.
#
# For example, to create a 2x2 grid of subplots, you can do the following:
#
# python

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data for line plot
x_line = np.linspace(0, 2 * np.pi, 100)
y_line = np.sin(x_line)

# Generate data for scatter plot
x_scatter = np.random.rand(50)
y_scatter = np.random.rand(50)

# Generate data for bar plot
x_bar = ['A', 'B', 'C', 'D', 'E']
y_bar = [3, 7, 2, 5, 8]

# Generate data for histogram
data_hist = np.random.randn(1000)

# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

# Line plot
axes[0, 0].plot(x_line, y_line)
axes[0, 0].set_title('Line Plot')

# Scatter plot
axes[0, 1].scatter(x_scatter, y_scatter)
axes[0, 1].set_title('Scatter Plot')

# Bar plot
axes[1, 0].bar(x_bar, y_bar)
axes[1, 0].set_title('Bar Plot')


# Histogram
axes[1, 1].hist(data_hist, bins=30)
axes[1, 1].set_title('Histogram')

plt.show()

# %% [markdown]
# By explicitly referencing the Axes objects, you can apply customizations and other functions to each individual plot.
#
# In summary, Matplotlib's pyplot interface provides a high-level way to interact with the underlying object hierarchy, making it easy to create and customize plots. Functions like plt.title() work with the current Figure and Axes objects to modify their elements, while more advanced control can be achieved by explicitly working with the objects themselves.

# %% [markdown]
# ## Hands-on Exercise: Creating and Customizing Basic Plots with Matplotlib

# %% [markdown]
# In this section, we will demonstrate how to create and customize various types of plots using Matplotlib's basic plotting functions. We will start with a simple line plot and then move on to other types of plots, such as scatter plots and bar plots. Finally, we will explore various customization techniques to enhance our visualizations.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a sine wave
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

# Create a line plot
plt.plot(x, y)
plt.title('Sinewave')
plt.show()

# %% [markdown]
# ## Creating Scatter and Bar Plots
# Now, let's create a scatter plot and a bar plot using the scatter() and bar() functions, respectively.

# %%
# Generate random data
x_scatter = np.random.rand(50)
y_scatter = np.random.rand(50)

# Create a scatter plot
plt.scatter(x_scatter, y_scatter)
plt.show()

# Generate data for a bar plot
x_bar = ['A', 'B', 'C', 'D', 'E']
y_bar = [3, 7, 2, 5, 8]

# Create a bar plot
plt.bar(x_bar, y_bar)
plt.show()

# %% [markdown]
# ## Customizing Plots
# Now, let's explore various customization techniques to enhance our plots. We will modify the appearance of our line plot and add titles, labels, and legends to our scatter and bar plots.

# %%
# Create a customized line plot
plt.plot(x, y, linestyle='--', color='red', linewidth=2, marker='o', markersize=5)
plt.title('Sine Wave')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Adding Titles, Labels, and Legends to Scatter and Bar Plots

# %%
# Create a customized scatter plot
plt.scatter(x_scatter, y_scatter, color='blue', marker='s', s=50, alpha=0.5, label='Random Points')
plt.title('Scatter Plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend(loc='upper right')
plt.show()

# Create a customized bar plot
plt.bar(x_bar, y_bar, color='green', edgecolor='black', width=0.5, label='Categories')
plt.title('Bar Plot')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# # Best Practices in Data Visualization
#
# In this section, we will cover some best practices for data visualization, focusing on choosing the right plot type, effectively using color, size, and shape, and making visualizations more informative and engaging.
#
# Choosing the Right Plot Type
# Selecting the appropriate plot type is crucial for effectively conveying the information in your data. Here are some general guidelines for choosing the right plot type based on the data and purpose:
#
#
# Line plots: Use for displaying continuous data over time or another continuous variable
#
#
# Bar plots: Use for comparing categorical data or showing the distribution of values across categories
#
#
# Scatter plots: Use for showing the relationship between two continuous variables
#
#
# Histograms: Use for displaying the distribution of a continuous variable
#
#
# Pie charts: Use for showing proportions of a whole (but use sparingly, as they can be difficult to interpret)
#
#
# Heatmaps: Use for representing data in a matrix format, using colors to indicate values
#
#
# Box plots: Use for visualizing the distribution of data and identifying outliers
#
#
# Area charts: Use for displaying continuous data over time or another continuous variable, with an emphasis on the magnitude
# Effective Use of Color, Size, and Shape
# Color, size, and shape are essential visual cues that can enhance your data visualizations. Here are some tips for using them effectively:
#
# Use color to group, differentiate, or highlight data points
# Choose colors that are easily distinguishable and accessible to people with color vision deficiencies
# Limit the number of colors used in a single plot to avoid clutter and confusion
# Use size and shape to add another dimension to your plots, allowing for the display of additional information
# Be consistent with the use of color, size, and shape across different visualizations to maintain coherence
# Tips for Making Visualizations More Informative and Engaging
# To make your visualizations more informative and engaging, consider the following tips:
#
# Add titles, axis labels, and legends to provide context and clarity
# Use appropriate scales and axis limits to emphasize the relevant information
# Annotate plots with text, arrows, or other shapes to highlight specific points or trends
# Apply gridlines and background colors to improve readability
# Customize the appearance of your plots (e.g., line styles, marker styles) to match the context or audience
# Visual Examples
# Now, let's create some visual examples that demonstrate these best practices. We will use a sample dataset from the Seaborn library.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load sample dataset
data = sns.load_dataset("iris")

# Create a scatter plot with customized colors, markers, and sizes
plt.figure(figsize=(8, 6))
for species, marker, color in zip(data['species'].unique(), ['o', 's', 'D'], ['blue', 'orange', 'green']):
    subset = data[data['species'] == species]
    plt.scatter(subset['sepal_length'], subset['sepal_width'], marker=marker, s=100, color=color, label=species, alpha=0.7)
plt.title('Iris Dataset: Sepal Length vs. Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend(title='Species')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# In this example, we've created a scatter plot that demonstrates several best practices:
#
# We've chosen an appropriate plot type (scatter plot) to show the relationship between two continuous variables
# We've used color and shape to differentiate between species
# We've added a title, axis labels, and a legend to provide context and clarity
# We've applied grid

# %% [markdown]
# Example 1: Consistent Scales on the Same Graph

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data
x = np.linspace(0, 2 * np.pi, 100)
y1 = np.sin(x)
y2 = 100 * np.cos(x)

# Create subplots with shared x-axis
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6))

# Plot data on separate axes to maintain consistent scales
ax1.plot(x, y1, label='Sine', color='blue')
ax1.set_title('Sine and Cosine Functions')
ax1.set_ylabel('Sine')
ax1.legend(loc='upper right')
ax1.grid(True, linestyle='--', alpha=0.5)

ax2.plot(x, y2, label='100 * Cosine', color='orange')
ax2.set_xlabel('x-axis')
ax2.set_ylabel('100 * Cosine')
ax2.legend(loc='upper right')
ax2.grid(True, linestyle='--', alpha=0.5)

plt.show()

# %% [markdown]
# Example 2: Avoiding Clutter in Bar Plots

# %%
import pandas as pd
import seaborn as sns

# Generate sample data
data = pd.DataFrame({'Category': ['A', 'B', 'C', 'D', 'E'] * 5,
                     'Value': np.random.randint(1, 10, 25),
                     'Group': ['Group 1'] * 5 + ['Group 2'] * 5 + ['Group 3'] * 5 + ['Group 4'] * 5 + ['Group 5'] * 5})

# Create bar plot with grouped categories
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Value', data=data)
plt.title('Bar Plot with Grouped Categories')
plt.xlabel('Category')
plt.ylabel('Value')
plt.legend(title='Group')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Interactive Data Visualization with Plotly
#
# In this section, we will explore how to create interactive data visualizations using the Plotly library. Plotly is a powerful Python library that allows you to create interactive, web-based visualizations with minimal code.
#
# ## Introduction to Plotly
# Plotly provides two main interfaces for creating interactive plots in Python: plotly.graph_objects and plotly.express. In this lesson, we will focus on using plotly.express, as it offers a simple, high-level interface for creating various types of plots.
#
# To get started with Plotly, you'll need to install the library:

# %%
# !pip install plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## Creating a Simple Interactive Plot
# Let's create a simple interactive scatter plot using the plotly.express module. We will use the Iris dataset, which is available in the seaborn library.

# %%
import plotly.express as px
import seaborn as sns

# Load the Iris dataset
data = sns.load_dataset("iris")

# Create an interactive scatter plot
fig = px.scatter(data, x="sepal_length", y="sepal_width", color="species", title="Iris Dataset: Sepal Length vs. Sepal Width")

# Display the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# In this example, we create an interactive scatter plot of the Iris dataset, using the sepal_length and sepal_width features. The plot is colored by the species column, and we've added a title to provide context.

# %% [markdown]
# # Customizing Interactive Plots
# You can easily customize the appearance and interactivity of your Plotly plots. Here's an example of a scatter plot with customized marker size, opacity, and hover information:

# %%
fig = px.scatter(data, x="sepal_length", y="sepal_width",
                 color="species",
                 size="petal_length",
                 opacity=0.7,
                 hover_name="species",
                 hover_data=["petal_width"],
                 title="Iris Dataset: Sepal Length vs. Sepal Width")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# In this example, we've customized the marker size based on the petal_length feature, set the opacity to 0.7, and added hover information for the species and petal_width columns.

# %% [markdown]
# ## Advanced Plotly Functions and Techniques
#
# In this section, we will explore some advanced functions and techniques available in the Plotly library, which can help you create more sophisticated and interactive visualizations.
#
# ## Customizing Hover Information
# Plotly's interactive plots include hover information by default, which displays the values of the data points when you hover your cursor over them. You can customize the hover information using the hover_data and hover_name parameters:

# %%
import plotly.express as px
import seaborn as sns

data = sns.load_dataset("iris")

fig = px.scatter(data, x="sepal_length", y="sepal_width",
                 color="species",
                 size="petal_length",
                 hover_data={"sepal_length": ":.2f", "sepal_width": ":.2f"},
                 hover_name="species",
                 title="Iris Dataset: Sepal Length vs. Sepal Width")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# In this example, we've customized the hover information to display the species as the hover name and formatted the sepal_length and sepal_width values to two decimal places.

# %% [markdown]
# ## Updating Marker Symbols and Text
# You can customize the appearance of markers in a scatter plot by updating their symbols and adding text labels. The symbol parameter can be used to set different marker symbols for each category, and the text parameter can be used to add text labels to the markers:

# %%
symbol_map = {'setosa': 'circle', 'versicolor': 'square', 'virginica': 'diamond'}

fig = px.scatter(data, x="sepal_length", y="sepal_width",
                 color="species",
                 symbol="species",
                 symbol_map=symbol_map,
                 text="species",
                 title="Iris Dataset: Sepal Length vs. Sepal Width")

fig.update_traces(textposition='top center', textfont_size=8)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Creating Subplots with Plotly
# Plotly allows you to create subplots using the plotly.subplots module. This enables you to display multiple related plots in a single figure, which can be useful for comparing different aspects of your data.
#
# Here's an example of a subplot with two scatter plots for the Iris dataset:

# %%
from plotly.subplots import make_subplots

fig = make_subplots(rows=1, cols=2, subplot_titles=("Sepal Length vs. Sepal Width", "Petal Length vs. Petal Width"))

scatter1 = px.scatter(data, x="sepal_length", y="sepal_width", color="species")
scatter2 = px.scatter(data, x="petal_length", y="petal_width", color="species")

for trace in scatter1.data:
    fig.add_trace(trace, row=1, col=1)

for trace in scatter2.data:
    fig.add_trace(trace, row=1, col=2)

fig.update_layout(title="Iris Dataset: Scatter Plots", showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# In this example, we've created a subplot with two scatter plots, one showing the relationship between sepal length and sepal width, and the other showing the relationship between petal length and petal width.

# %% [markdown]
# ## Other Advanced Plot Types
# Plotly supports a variety of advanced plot types that can be used to visualize complex relationships and distributions in your data. Some of these plot types include:
#
# 3D Scatter plots: px.scatter_3d()
#
# Parallel Coordinates plots: px.parallel_coordinates()
#
# Sunburst plots: px.sunburst()
#
# Treemaps: px.treemap()
#
# Choropleth maps: px.choropleth()
#
# Sankey diagrams: px.sankey()

# %% [markdown]
# ## Other Interactive Plot Types
# Plotly Express supports a wide variety of interactive plot types. Some examples include:
#
# Line plots: px.line()
#
# Bar plots: px.bar()
#
# Histograms: px.histogram()
#
# Box plots: px.box()
#
# Heatmaps: px.imshow() (for image-like data) or px.
#
# density_heatmap() (for point data)
#
# To create these plots, you can simply replace the px.scatter() function with the appropriate function for your desired plot type and adjust the input parameters accordingly.
#
# In this section, we've introduced Plotly, a powerful library for creating interactive data visualizations in Python.
#
# By using the plotly.express module, you can easily create a variety of plot types and customize their appearance and interactivity.

# %% [markdown]
# ## Animations
# Plotly also supports creating animations, which can help you visualize how your data changes over time or across different conditions. Here's an example of an animated scatter plot using the animation_frame parameter:

# %%
import pandas as pd

# Create a sample dataset with random data
data = pd.DataFrame({
    'x': np.random.randn(100),
    'y': np.random.randn(100),
    'size': np.random.randint(10, 100, size=100),
    'time': np.random.randint(1, 5, size=100)
})

fig = px.scatter(data, x="x", y="y", size="size", color="size",
                 animation_frame="time",
                 title="Animated Scatter Plot")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# In this example, we've created an animated scatter plot that shows how the data points change over time. The animation_frame parameter is set to the time column, which determines the frames for the animation.
#
# In this section, we've explored some advanced functions and techniques available in the Plotly library. These features allow you to create more sophisticated and interactive visualizations, helping you effectively analyze and present your data

# %% [markdown]
# ## Data Visualization with Seaborn
#
# In this section, we will explore how to create visually appealing and informative data visualizations using the Seaborn library. Seaborn is a Python library built on top of Matplotlib, providing a high-level interface for statistical graphics.

# %% [markdown]
# ## Introduction to Seaborn
# Seaborn comes with several built-in themes and color palettes that make it easy to create aesthetically pleasing visualizations with minimal effort. It also integrates well with Pandas DataFrames, which simplifies the process of working with complex datasets.
#
# To get started with Seaborn, you'll need to install the library:

# %% [markdown]
# ## Creating a Simple Seaborn Plot
# Let's create a simple scatter plot using the seaborn module. We will use the Iris dataset, which is available in the seaborn library.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
data = sns.load_dataset("iris")

# Create a scatter plot
sns.scatterplot(x="sepal_length", y="sepal_width", hue="species", data=data)

# Add plot title and axis labels
plt.title("Iris Dataset: Sepal Length vs. Sepal Width")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")

plt.show()

# %% [markdown]
# In this example, we create a scatter plot of the Iris dataset, using the sepal_length and sepal_width features. The plot is colored by the species column, and we've added a title and axis labels to provide context.

# %% [markdown]
# ## Customizing Seaborn Plots
# Seaborn offers a variety of customization options for your plots, including style and color palettes. Here's an example of a scatter plot with a custom style and color palette:

# %%
# Set Seaborn style and color palette
sns.set_style("whitegrid")
sns.set_palette("husl")

# Create a scatter plot
sns.scatterplot(x="sepal_length", y="sepal_width", hue="species", data=data, s=80, alpha=0.8)

# Add plot title and axis labels
plt.title("Iris Dataset: Sepal Length vs. Sepal Width")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")

plt.show()

# %% [markdown]
# In this example, we've set the Seaborn style to "whitegrid" and the color palette to "husl". We've also customized the marker size and opacity for the scatter plot.

# %% [markdown]
# ## Other Seaborn Plot Types
# Seaborn supports a wide variety of plot types that can be used to visualize complex datasets and relationships. Some examples include:
#
# Line plots: sns.lineplot()
#
# Bar plots: sns.barplot()
#
# Histograms: sns.histplot()
#
# Box plots: sns.boxplot()
#
# Violin plots: sns.violinplot()
#
# Heatmaps: sns.heatmap()
#
# Pair plots: sns.pairplot()
#
# Joint plots: sns.jointplot()
#
# To create these plots, you can simply replace the sns.
#
# scatterplot() function with the appropriate function for your desired plot type and adjust the input parameters accordingly.
#
# In this section, we've introduced Seaborn, a powerful library for creating visually appealing and informative data visualizations in Python. By using Seaborn's built-in themes, color palettes, and plot functions, you can easily create a variety of plot types to analyze and present your data.

# %% [markdown]
# # Advanced Seaborn Controls and Plotting Techniques
#
# In this section, we will dive deeper into Seaborn's features and explore some advanced controls and plotting techniques that can be used to create more complex and informative visualizations.
#
# ## Seaborn Plot Customization
# Seaborn offers various customization options that allow you to create tailored plots that suit your needs. Here are some aspects you can customize:
#
# ## Figure Size and Aspect Ratio
# You can control the figure size and aspect ratio by using the plt.subplots() function from Matplotlib before creating your Seaborn plot:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = sns.load_dataset("iris")

# Set the figure size
fig, ax = plt.subplots(figsize=(10, 6))

# Create a scatter plot
sns.scatterplot(x="sepal_length", y="sepal_width", hue="species", data=data, ax=ax)

# Add plot title and axis labels
plt.title("Iris Dataset: Sepal Length vs. Sepal Width")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")

plt.show()

# %% [markdown]
# ## Seaborn Styles and Contexts
# Seaborn provides five built-in styles: darkgrid, whitegrid, dark, white, and ticks. You can set the style using the sns.set_style() function:

# %%
# Set the Seaborn style
sns.set_style("ticks")

# %% [markdown]
# Seaborn also offers four predefined contexts: paper, notebook, talk, and poster. These contexts adjust the size of various elements in your plots, such as fonts and line widths, to make them suitable for different presentation formats. You can set the context using the sns.set_context() function:

# %%
# Set the Seaborn context
sns.set_context("talk")

# %% [markdown]
# ## FacetGrid for Multi-Panel Plots
# Seaborn's FacetGrid is a powerful tool for creating multi-panel plots that display subsets of your data across different panels. This can help you explore and compare relationships between variables across different categories or conditions.
#
# Here's an example of a FacetGrid with scatter plots for the Iris dataset, separated by species:

# %%
g = sns.FacetGrid(data, col="species")
g.map(sns.scatterplot, "sepal_length", "sepal_width")
g.set_axis_labels("Sepal Length (cm)", "Sepal Width (cm)")
plt.show()

# %% [markdown]
# ## Advanced Plot Types
# Seaborn offers a variety of advanced plot types that can be used to visualize complex relationships and distributions in your data. Some of these plot types include:
#
# ## Kernel Density Estimation (KDE) Plot
# A KDE plot visualizes the distribution of a continuous variable by estimating the probability density function of the data. You can create a KDE plot using the sns.kdeplot() function:

# %%
sns.kdeplot(data=data, x="sepal_length", hue="species")
plt.title("KDE Plot of Sepal Length")
plt.xlabel("Sepal Length (cm)")
plt.show()

# %% [markdown]
# ## Swarm Plot
# A swarm plot is similar to a strip plot, but the data points are adjusted along the categorical axis to avoid overlap. This makes it easier to visualize the distribution of data points within each category. You can create a swarm plot using the sns.swarmplot() function:

# %%
sns.swarmplot(data=data, x="species", y="sepal_length")
plt.title("Swarm Plot of Sepal Length by Species")
plt.xlabel("Species")
plt.ylabel("Sepal Length")
# Out:
# Text(42.722222222222214, 0.5, 'Sepal Length')

# %% [markdown]
# # Case Study: Startup X Product Performance Analysis
#
# Startup X is a tech company that recently launched a new mobile app called "FitBuddy". FitBuddy is a fitness tracking and social networking app that allows users to log their workouts, track their progress, and connect with friends for motivation and friendly competition.
#
# The app has three subscription plans: Free, Pro, and Elite. The Free plan offers basic workout tracking and social networking features, the Pro plan adds advanced analytics and training plans, and the Elite plan includes personalized coaching and priority customer support.
#
# Startup X executives are keen to understand the performance of their new product and identify areas for improvement. They would like to analyze user data to answer questions about user engagement, subscription plan preferences, and the effectiveness of their marketing efforts.

# %%
import numpy as np
import pandas as pd
import random

np.random.seed(42)
random.seed(42)

n_users = 1000

user_id = list(range(1, n_users + 1))
subscription_plans = ['Free', 'Pro', 'Elite']
plan_choices = [random.choice(subscription_plans) for _ in range(n_users)]

age = np.random.randint(18, 65, size=n_users)
signup_source = np.random.choice(['Organic', 'Facebook', 'Google'], size=n_users, p=[0.4, 0.3, 0.3])
workouts_per_week = np.random.randint(0, 8, size=n_users)
average_workout_duration = np.random.randint(15, 121, size=n_users)

user_data = pd.DataFrame({
    'user_id': user_id,
    'plan': plan_choices,
    'age': age,
    'signup_source': signup_source,
    'workouts_per_week': workouts_per_week,
    'average_workout_duration': average_workout_duration
})

user_data.head()
# Out:
#    user_id   plan  age signup_source  workouts_per_week  \
# 0        1  Elite   56       Organic                  5
# 1        2   Free   46        Google                  7
# 2        3   Free   32       Organic                  4
# 3        4  Elite   60      Facebook                  2
# 4        5    Pro   25        Google                  5
#
#    average_workout_duration
# 0                       101
# 1                        36
# 2                        62
# 3                        97
# 4                        65

# %% [markdown]
# # Questions for Students
# How many users are subscribed to each plan (Free, Pro, and Elite)?
#
# Create a bar plot to visualize the number of users in each subscription plan.
#
# What is the average age of users for each subscription plan?
#
# Create a box plot to visualize the age distribution for each subscription plan.
#
# What is the most common source of signups for each subscription plan?
#
# Create a stacked bar plot to visualize the number of users in each subscription
# plan by signup source.
#
# What is the average number of workouts per week for each subscription plan?
#
# Create a violin plot to visualize the distribution of workouts per week for each subscription plan.
#
# What is the average workout duration for each subscription plan?
#
# Create a scatter plot to visualize the relationship between workouts per week and average workout duration for each subscription plan
